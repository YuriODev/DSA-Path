# %% [markdown]
# # <a id='toc1_'></a>[Day 1: Introduction to Algorithms & Time Complexity Basics 🚀](#toc0_)

# %% [markdown]
# ## <a id='toc1_1_'></a>[Table of Contents 📖](#toc0_)

# %% [markdown]
# - [Table of Contents 📖](#toc1_1_)
# - [Objectives](#toc1_2_)
# - [Theory](#toc1_3_)
#   - [What is an Algorithm? 🤖](#toc1_3_1_)
#   - [Introduction to Time Complexity ⏱️](#toc1_3_2_)
# - [Problems & Exercises](#toc1_4_)
#   - [Exercise 1: Algorithm Identification 💭](#toc1_4_1_)
#     - [Solution for Exercise 1: Algorithm Identification](#toc1_4_1_1_)
#   - [Exercise 2: Time Complexity Analysis ⏳](#toc1_4_2_)
#     - [Solution for Exercise 2: Time Complexity Analysis](#toc1_4_2_1_)
#   - [Exercise 3: Comparative Analysis ⚖️](#toc1_4_3_)
#     - [Solution for Exercise 3: Comparative Analysis](#toc1_4_3_1_)
# - [Code Examples & Visualizations 💻](#toc1_5_)
#   - [Code Example: Summing a List (Linear Algorithm) 📝](#toc1_5_1_)
#   - [Code Example: Using Python's Built-in `sum()` Function ⚡](#toc1_5_2_)
#   - [Visualization: Plotting Runtime vs. Input Size 📊](#toc1_5_3_)
#   - [Comparative Graph: Theoretical Time Complexities 🌈](#toc1_5_4_)
# - [Industry Use Cases 🚀](#toc1_6_)
# - [Conclusion & Further Reading 📚](#toc1_7_)
#
# <!-- vscode-jupyter-toc-config
# numbering=false
# anchor=true
# flat=false
# minLevel=1
# maxLevel=6
# /vscode-jupyter-toc-config -->
# <!-- THIS CELL WILL BE REPLACED ON TOC UPDATE. DO NOT WRITE YOUR TEXT IN THIS CELL -->

# %% [markdown]
# ## <a id='toc1_2_'></a>[Objectives](#toc0_)

# %% [markdown]
# - **Define what an algorithm is:** Understand its characteristics and importance. 🤖
# - **Introduce time complexity:** Learn what time complexity means and why it matters. ⏱️
# - **Familiarize with Big-O notation:** Recognize common time complexities such as O(1), O(n), O(log n), etc. 📐
# - **Appreciate algorithm efficiency:** Understand how efficient algorithms impact real-world applications. 💡

# %% [markdown]
# ## <a id='toc1_3_'></a>[Theory](#toc0_)

# %% [markdown]
# ### <a id='toc1_3_1_'></a>[What is an Algorithm? 🤖](#toc0_)

# %% [markdown]
# **Definition:** An algorithm is a finite, step-by-step procedure for solving a problem or performing a task.
#
# **Key Characteristics:**
# - **Input/Output:** Accepts input and produces output.
# - **Definiteness:** Each step is clearly defined with no ambiguity.
# - **Finiteness:** The process must conclude after a finite number of steps.
# - **Effectiveness:** Each step must be simple enough to be executed, typically by a computer.
#
# **Deep Dive:**
# Algorithms form the backbone of all computing processes. They are used not only in computer science but also in everyday tasks. For example, a cooking recipe is an algorithm: you have ingredients (input) and a delicious dish (output) 🍰.
#
# Designing an algorithm involves breaking down a problem into smaller, manageable parts and then solving each part in a logical sequence. This systematic approach boosts problem-solving skills and ensures efficiency. 🚀

# %% [markdown]
# ### <a id='toc1_3_2_'></a>[Introduction to Time Complexity ⏱️](#toc0_)

# %% [markdown]
# **Definition:** Time complexity describes the amount of time an algorithm takes to run as a function of the input size.
#
# **Big-O Notation:**
# Big-O notation provides an upper bound on the growth rate of an algorithm's running time. It allows us to compare the efficiency of different algorithms at a glance.
#
# **Common Time Complexities:**
# - **O(1) – Constant Time:** Execution time remains constant regardless of input size. ⚡
# - **O(log n) – Logarithmic Time:** Execution time increases logarithmically as input size increases. 🔍
# - **O(n) – Linear Time:** Execution time grows linearly with the input size. 📈
# - **O(n²) – Quadratic Time:** Execution time grows proportionally to the square of the input size. 📊
#
# **Additional Considerations:**
# - **Best-case, Average-case, Worst-case:** Different scenarios can influence performance analysis.
# - **Amortized Analysis:** Sometimes, a costly operation is rare and is offset by many cheaper ones.
#
# Understanding time complexity is crucial when processing large datasets, as inefficient algorithms can lead to significant delays and resource usage. 🔥

# %% [markdown]
# ## <a id='toc1_4_'></a>[Problems & Exercises](#toc0_)

# %% [markdown]
# ### <a id='toc1_4_1_'></a>[Exercise 1: Algorithm Identification 💭](#toc0_)

# %% [markdown]
# **Task:** Write down three everyday tasks (e.g., making coffee, organizing books, planning a trip) and describe the algorithmic steps involved.
# **Goal:** Recognize how algorithmic thinking applies to real-world processes. 📝

# %% [markdown]
# #### <a id='toc1_4_1_1_'></a>[Solution for Exercise 1: Algorithm Identification](#toc0_)

# %% [markdown]
# **Example Solutions:**
#
# 1. **Making Coffee:**
#    - **Step 1:** Boil water.
#    - **Step 2:** Grind coffee beans.
#    - **Step 3:** Brew coffee by mixing water with ground coffee.
#    - **Step 4:** Pour coffee into a cup and add milk/sugar as desired.
#
# 2. **Organizing Books:**
#    - **Step 1:** Collect all books.
#    - **Step 2:** Sort books by genre or subject.
#    - **Step 3:** Arrange each category alphabetically or by size.
#
# 3. **Planning a Trip:**
#    - **Step 1:** Decide on a destination.
#    - **Step 2:** Research transportation options and book tickets.
#    - **Step 3:** Find and reserve accommodation.
#    - **Step 4:** Create a daily itinerary including sightseeing and dining options.
#
# ```mermaid
# flowchart TD
#     A[Decide on Destination] --> B[Research Transportation]
#     B --> C[Book Tickets]
#     C --> D[Reserve Accommodation]
#     D --> E[Plan Itinerary]
# ```

# %% [markdown]
# ### <a id='toc1_4_2_'></a>[Exercise 2: Time Complexity Analysis ⏳](#toc0_)

# %% [markdown]
# **Task:**
# - Write a Python function to sum the elements in a list.
# - Analyze its time complexity.
#
# **Extension:** Use Jupyter’s `%timeit` magic command to measure the function’s execution time for various input sizes.
# **Goal:** Connect code performance with theoretical time complexity. 🔍

# %% [markdown]
# #### <a id='toc1_4_2_1_'></a>[Solution for Exercise 2: Time Complexity Analysis](#toc0_)

# %% [markdown]
# The provided function `sum_list(numbers)` iterates through each element of the list exactly once, giving it a time complexity of **O(n)**.
#
# Using `%timeit` confirms that the runtime increases linearly with the input size.
#
# ```mermaid
# flowchart TD
#     A[Start] --> B[Initialize total = 0]
#     B --> C[For each number in list]
#     C --> D[Add number to total]
#     D --> E[Return total]
# ```

# %% [markdown]
# ### <a id='toc1_4_3_'></a>[Exercise 3: Comparative Analysis ⚖️](#toc0_)

# %% [markdown]
# **Task:**
# - Implement two functions: one that sums a list using a simple loop and another using Python’s built-in `sum()` function.
# - Compare their execution times.
#
# **Goal:** Understand how built-in optimizations may affect performance. 💪

# %% [markdown]
# #### <a id='toc1_4_3_1_'></a>[Solution for Exercise 3: Comparative Analysis](#toc0_)

# %% [markdown]
# After implementing both methods, we observe that:
#
# - The custom function `sum_list(numbers)` takes longer due to the overhead of a Python loop (O(n)).
# - The built-in `sum()` function, implemented in C, is much faster despite both having O(n) complexity.
#
# ```mermaid
# flowchart LR
#     A["Custom Sum"] -->|Loop Iteration| B["O(n) Time"]
#     C["Built-in Sum"] -->|Optimized in C| D["Lower Constant Time"]
# ```

# %% [markdown]
# ## <a id='toc1_5_'></a>[Code Examples & Visualizations 💻](#toc0_)

# %% [markdown]
# ### <a id='toc1_5_1_'></a>[Code Example: Summing a List (Linear Algorithm) 📝](#toc0_)

# %% [markdown]
# In this example, we define a function that sums the elements of a list using a loop. This demonstrates a linear time (O(n)) approach. 🔄

# %%
def sum_list(numbers):
    total = 0
    for num in numbers:
        total += num
    return total

# %% [markdown]
# The function `sum_list` iterates over each element in the list and accumulates the sum. Since the loop runs once per element, the time complexity is **O(n)**. ⏱️

# %%
data = list(range(10000))
print("Sum:", sum_list(data))
# Out:
# Sum: 49995000

# %% [markdown]
# The output `Sum: 49995000` confirms that the `sum_list` function correctly sums numbers from 0 to 9999.

# %% [markdown]
# Now, let's measure the execution time of `sum_list` using Jupyter's `%timeit` magic command:

# %%
# %timeit sum_list(data)
# Out:
# 98.5 μs ± 2.36 μs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# The `%timeit` output shows the average execution time for the custom `sum_list` function over multiple runs.

# %% [markdown]
# ### <a id='toc1_5_2_'></a>[Code Example: Using Python's Built-in `sum()` Function ⚡](#toc0_)

# %%
result = sum(data)
print("Built-in Sum:", result)
# Out:
# Built-in Sum: 49995000

# %% [markdown]
# The built-in `sum()` function returns the same result (`49995000`), but is more optimized due to its underlying C implementation.

# %% [markdown]
# Measure the execution time of the built-in `sum()` function:

# %%
# %timeit sum(data)
# Out:
# 26.6 μs ± 47.1 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# The `%timeit` result for the built-in `sum()` function is significantly lower than that of the custom function, demonstrating its superior performance.

# %% [markdown]
# ### <a id='toc1_5_3_'></a>[Visualization: Plotting Runtime vs. Input Size 📊](#toc0_)

# %%
import matplotlib.pyplot as plt
import numpy as np
import time

def linear_time_function(n):
    start = time.time()
    total = 0
    for i in range(n):
        total += i
    return time.time() - start

# Generate sample input sizes
sizes = np.linspace(1000, 10000, 10, dtype=int)
times = [linear_time_function(n) for n in sizes]

display("Measured Times:", times)
# Out:
# 'Measured Times:'
# [2.002716064453125e-05,
#  2.6226043701171875e-05,
#  5.1975250244140625e-05,
#  5.602836608886719e-05,
#  8.082389831542969e-05,
#  7.82012939453125e-05,
#  0.00012493133544921875,
#  0.00012087821960449219,
#  0.00012922286987304688,
#  0.00013589859008789062]

# %%
plt.figure(figsize=(10, 6))
plt.plot(sizes, times, linestyle='-', color='teal', marker='o', label='O(n) - Linear')
plt.xlabel("Input Size (n)")
plt.ylabel("Time (seconds)")
plt.title("Runtime vs. Input Size for a Linear Algorithm")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# The graph shows that the runtime increases linearly with the input size, confirming the **O(n)** time complexity of the algorithm.

# %% [markdown]
# ### <a id='toc1_5_4_'></a>[Comparative Graph: Theoretical Time Complexities 🌈](#toc0_)

# %%
x = np.linspace(1, 40, 40)
constant = np.ones_like(x) * 5  # constant value scaled for visualization
logarithmic = np.log(x) * 10
linear = x
quadratic = (x ** 2) / 20

plt.figure(figsize=(10, 6))
plt.plot(x, constant, label='O(1) - Constant', linestyle='-', color='red')
plt.plot(x, logarithmic, label='O(log n) - Logarithmic', linestyle='--', color='green')
plt.plot(x, linear, label='O(n) - Linear', linestyle='-.', color='blue')
plt.plot(x, quadratic, label='O(n²) - Quadratic', linestyle=':', color='purple')

plt.xlabel("Input Size (n)")
plt.ylabel("Operations (normalized)")
plt.title("Comparison of Time Complexities")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# The comparative graph illustrates the growth rates of different time complexities, showing that:
# - **O(1)** remains constant,
# - **O(log n)** grows very slowly,
# - **O(n)** grows linearly, and
# - **O(n²)** grows quadratically with input size.

# %% [markdown]
# ## <a id='toc1_6_'></a>[Industry Use Cases 🚀](#toc0_)

# %% [markdown]
# - **Web Applications:** Efficient algorithms ensure fast response times for millions of users. 🌐
# - **Data Analytics:** Algorithms with low time complexity are crucial for processing large datasets quickly. 📊
# - **Real-Time Systems:** Optimal algorithms maintain performance under heavy loads in systems like financial trading platforms. 💹
# - **Mobile Applications:** Speedy algorithms help deliver smooth and responsive user experiences on mobile devices. 📱

# %% [markdown]
# ## <a id='toc1_7_'></a>[Conclusion & Further Reading 📚](#toc0_)

# %% [markdown]
# **Summary:**
# - An algorithm is a precise, step-by-step procedure to solve a problem efficiently. 🤖
# - Time complexity, expressed using Big-O notation, is vital for understanding algorithm performance. ⏱️
# - Practical examples and visualizations help in understanding how algorithms scale with input size. 📈
#
# **Reflection Questions:**
# - How does algorithm efficiency affect performance in large-scale systems? 🔍
# - What trade-offs must be considered when choosing between different algorithmic approaches? 🤔
#
# **Additional Resources:**
# - [Introduction to Algorithms (CLRS)](https://mitpress.mit.edu/books/introduction-to-algorithms) 📘
# - [MIT OpenCourseWare - Introduction to Algorithms](https://ocw.mit.edu/courses/electrical-engineering-and-computer-science/6-006-introduction-to-algorithms-fall-2011/) 🎓
# - [GeeksforGeeks Algorithms](https://www.geeksforgeeks.org/fundamentals-of-algorithms/) 💻
# - [Khan Academy Algorithms](https://www.khanacademy.org/computing/computer-science/algorithms) 🌟
# - [Coursera - Algorithms Specialization](https://www.coursera.org/specializations/algorithms) 🎯
